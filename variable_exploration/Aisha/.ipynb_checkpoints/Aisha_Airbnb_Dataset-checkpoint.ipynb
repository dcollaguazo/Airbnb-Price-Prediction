# %%
import os
import io
import re
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv("listings.csv.gz") 
data.head()
# Out:
#      id                        listing_url       scrape_id last_scraped  \
# 0  2060  https://www.airbnb.com/rooms/2060  20200313233810   2020-03-14
# 1  2595  https://www.airbnb.com/rooms/2595  20200313233810   2020-03-14
# 2  3831  https://www.airbnb.com/rooms/3831  20200313233810   2020-03-14
# 3  5099  https://www.airbnb.com/rooms/5099  20200313233810   2020-03-14
# 4  5114  https://www.airbnb.com/rooms/5114  20200313233810   2020-03-14
#
#                                         name  \
# 0                                 Modern NYC
# 1                      Skylit Midtown Castle
# 2            Cozy Entire Floor of Brownstone
# 3  Large Cozy 1 BR Apartment In Midtown East
# 4                  Super Room in Great area.
#
#                                              summary  \
# 0                                                NaN
# 1  Beautiful, spacious skylit studio in the heart...
# 2  Urban retreat: enjoy 500 s.f. floor in 1899 br...
# 3  My large 1 bedroom apartment has a true New Yo...
# 4                                                NaN
#
#                                                space  \
# 0  Lovely, spacious, sunny 1 BR apartment in 6th ...
# 1  - Spacious (500+ft²), immaculate and nicely fu...
# 2  Greetings!      We own a double-duplex brownst...
# 3  I have a large 1 bedroom apartment centrally l...
# 4  First, the area is PERFECT if you want to visi...
#
#                                          description experiences_offered  \
# 0  Lovely, spacious, sunny 1 BR apartment in 6th ...                none
# 1  Beautiful, spacious skylit studio in the heart...                none
# 2  Urban retreat: enjoy 500 s.f. floor in 1899 br...                none
# 3  My large 1 bedroom apartment has a true New Yo...                none
# 4  First, the area is PERFECT if you want to visi...                none
#
#                                neighborhood_overview  ... instant_bookable  \
# 0                                                NaN  ...                f
# 1  Centrally located in the heart of Manhattan ju...  ...                f
# 2  Just the right mix of urban center and local n...  ...                f
# 3  My neighborhood in Midtown East is called Murr...  ...                f
# 4                                                NaN  ...                f
#
#   is_business_travel_ready          cancellation_policy  \
# 0                        f                     flexible
# 1                        f  strict_14_with_grace_period
# 2                        f                     moderate
# 3                        f                     moderate
# 4                        f  strict_14_with_grace_period
#
#   require_guest_profile_picture require_guest_phone_verification  \
# 0                             f                                f
# 1                             t                                t
# 2                             f                                f
# 3                             t                                t
# 4                             f                                f
#
#    calculated_host_listings_count  \
# 0                               1
# 1                               2
# 2                               1
# 3                               1
# 4                               3
#
#    calculated_host_listings_count_entire_homes  \
# 0                                            0
# 1                                            2
# 2                                            1
# 3                                            1
# 4                                            1
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            1
# 1                                            0
# 2                                            0
# 3                                            0
# 4                                            2
#
#    calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                            0               0.01
# 1                                            0               0.38
# 2                                            0               4.71
# 3                                            0               0.59
# 4                                            0               0.56
#
# [5 rows x 106 columns]

# %%
len(data)
# Out:
# 50796

# %%
#to get a count of missing values for each column, and what percent of each column is null 
data.isnull().sum()

total = data.isnull().sum().sort_values(ascending=False)
percent = (data.isnull().sum())/data.isnull().count().sort_values(ascending=False)

missing_data = pd.concat([total, percent], axis=1, keys=['Total','Percent'], sort=False).sort_values('Total', ascending=False)
missing_data.head(25)
# Out:
#                              Total   Percent
# thumbnail_url                50796  1.000000
# xl_picture_url               50796  1.000000
# medium_url                   50796  1.000000
# jurisdiction_names           50781  0.999705
# license                      50759  0.999272
# square_feet                  50407  0.992342
# monthly_price                46119  0.907926
# weekly_price                 45411  0.893988
# notes                        30273  0.595972
# access                       23984  0.472163
# interaction                  20436  0.402315
# host_about                   20325  0.400130
# house_rules                  19860  0.390976
# host_response_time           19006  0.374163
# host_response_rate           19006  0.374163
# transit                      17472  0.343964
# neighborhood_overview        17468  0.343885
# security_deposit             17325  0.341070
# space                        14199  0.279530
# host_acceptance_rate         14015  0.275908
# review_scores_value          11482  0.226041
# review_scores_location       11482  0.226041
# review_scores_checkin        11479  0.225982
# review_scores_accuracy       11466  0.225726
# review_scores_communication  11463  0.225667

# %%
#remove columns with 50% or more null values 
   
data.drop(['thumbnail_url','xl_picture_url','medium_url','jurisdiction_names','license','square_feet','monthly_price','weekly_price','notes'], axis=1, inplace=True)

# %%
#fill certain attributes with 0 if n/a 
data['reviews_per_month'] = data['reviews_per_month'].fillna(0)
data['bathrooms'] = data['bathrooms'].fillna(0)
data['bedrooms'] = data['bedrooms'].fillna(0)
data['security_deposit'] = data['security_deposit'].fillna(0)
data['space'] = data['space'].fillna(0)

# %%
#data exploration: see which hosts have the most listings
host_listings=data.host_id.value_counts().head(10)
host_listings
# Out:
# 107434423    302
# 219517861    297
# 137358866    136
# 30283594     116
# 16098958     112
# 61391963     109
# 48005494     103
# 51501835      92
# 12243051      89
# 22541573      88
# Name: host_id, dtype: int64

# %%
#visualization for latitude/longitude concentration areas
fig, axes = plt.subplots(1,3, figsize=(20,5))
sns.distplot(data['latitude'], ax=axes[0])
sns.distplot(data['longitude'], ax=axes[1])
sns.scatterplot(x= data['latitude'], y=data['longitude'], hue=data['neighbourhood_group_cleansed'])

# %%
#visualization for type of room
sns.catplot(x='room_type', kind='count' ,data=data)
fig = plt.gcf()
fig.set_size_inches(5, 5)

# %%
#Get a count by borough
borough_count = data.groupby('neighbourhood_group_cleansed').agg('count').reset_index()

#listings by borough
fig, ax1 = plt.subplots(1,1, figsize=(6,6)
                       )
sns.barplot(x='neighbourhood_group_cleansed', y='id', data=borough_count, ax=ax1)

ax1.set_title('Number of Listings by Borough', fontsize=15)
ax1.set_xlabel('neighbourhood_group_cleansed', fontsize=12)
ax1.set_ylabel('Count', fontsize=12)
ax1.tick_params(axis='both', labelsize=10)

# %%
#function to replace
def convert_bool(row):
    row = row.replace('f', '0')
    row = row.replace('t', '1')
    return row


#function to replace
def convert_string_to_int(row):
    row = row.replace('within an hour', '1')
    row = row.replace('within a few hours', '2')
    row = row.replace('within a day', '3')
    row = row.replace('a few days or more', '4')
    return row

# %%
# Extract the names of columns that are Numeric
numeric_data=data._get_numeric_data().columns

# Extract the names of columns that are Categorical
categorical_data=set(data.columns)-set(numeric_data)

# %%
print (categorical_data)
# Out:
# {'host_response_rate', 'requires_license', 'host_picture_url', 'property_type', 'host_has_profile_pic', 'transit', 'host_response_time', 'last_scraped', 'space', 'host_verifications', 'room_type', 'host_is_superhost', 'street', 'market', 'amenities', 'extra_people', 'price', 'security_deposit', 'access', 'host_acceptance_rate', 'instant_bookable', 'picture_url', 'country', 'first_review', 'neighbourhood_cleansed', 'bed_type', 'calendar_last_scraped', 'host_since', 'description', 'cleaning_fee', 'is_location_exact', 'smart_location', 'calendar_updated', 'host_name', 'has_availability', 'host_neighbourhood', 'require_guest_phone_verification', 'host_thumbnail_url', 'host_about', 'name', 'host_location', 'zipcode', 'host_url', 'is_business_travel_ready', 'neighbourhood_group_cleansed', 'require_guest_profile_picture', 'neighborhood_overview', 'last_review', 'country_code', 'state', 'summary', 'interaction', 'listing_url', 'house_rules', 'cancellation_policy', 'city', 'host_identity_verified', 'neighbourhood', 'experiences_offered'}

# %%
print (numeric_data)
# Out:
# Index(['id', 'scrape_id', 'host_id', 'host_listings_count',
#        'host_total_listings_count', 'latitude', 'longitude', 'accommodates',
#        'bathrooms', 'bedrooms', 'beds', 'guests_included', 'minimum_nights',
#        'maximum_nights', 'minimum_minimum_nights', 'maximum_minimum_nights',
#        'minimum_maximum_nights', 'maximum_maximum_nights',
#        'minimum_nights_avg_ntm', 'maximum_nights_avg_ntm', 'availability_30',
#        'availability_60', 'availability_90', 'availability_365',
#        'number_of_reviews', 'number_of_reviews_ltm', 'review_scores_rating',
#        'review_scores_accuracy', 'review_scores_cleanliness',
#        'review_scores_checkin', 'review_scores_communication',
#        'review_scores_location', 'review_scores_value',
#        'calculated_host_listings_count',
#        'calculated_host_listings_count_entire_homes',
#        'calculated_host_listings_count_private_rooms',
#        'calculated_host_listings_count_shared_rooms', 'reviews_per_month'],
#       dtype='object')

# %%
def fix_currency(row):
    row = row.replace(',', '')
    row = row.replace('$', '')
    return row

# %%
from re import sub
from decimal import Decimal

money = '$6,150,593.22'
value = Decimal(sub(r'[^\d.]', '', money))

# %%
filt = data['id'] == 16202962
data[['price', 'cleaning_fee']][filt].head()
# Out:
#          price cleaning_fee
# 18057  $120.00       $65.00

# %%
#fill with 0
Fill_with_zero = ['bathrooms', 'bedrooms', 'host_is_superhost', 'beds', 'review_scores_rating', 'review_scores_accuracy',
'review_scores_cleanliness', 'review_scores_checkin', 'review_scores_communication', 'review_scores_location', 'review_scores_value', 'reviews_per_month']

for column in Fill_with_zero:
    data[column] = data[column].replace(np.nan, '0')
    
#fill with $0.00
Fill_with_zero = ['security_deposit', 'cleaning_fee']

for column in Fill_with_zero:
    data[column] = data[column].replace(np.nan, '$0.00')

# %%
#trying out the test/train split for linear regression -- we will put 40% of the dataset as a test

from sklearn.model_selection import train_test_split

X = data[["reviews_per_month", "bathrooms", "bedrooms"]]
y = data["price"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()

# %%
regressor.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-cb9aa30858d7> in <module>
# ----> 1 regressor.fit(X_train, y_train)
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\_base.py in fit(self, X, y, sample_weight)
#     504         n_jobs_ = self.n_jobs
#     505         X, y = self._validate_data(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 506                                    y_numeric=True, multi_output=True)
#     507
#     508         if sample_weight is not None:
#
# ~\Anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     430                 y = check_array(y, **check_y_params)
#     431             else:
# --> 432                 X, y = check_X_y(X, y, **check_params)
#     433             out = X, y
#     434
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#     809         _assert_all_finite(y)
#     810     if y_numeric and y.dtype.kind == 'O':
# --> 811         y = y.astype(np.float64)
#     812
#     813     check_consistent_length(X, y)
#
# ValueError: could not convert string to float: '$95.00'

# %%
regressor.predict(X_test)

# %%
from yellowbrick.regressor import PredictionError
viz = PredictionError(LinearRegression())
viz.fit(X_train, y_train)
viz.score(X_test, y_test)
viz.show()

# %%
from yellowbrick.regressor import ResidualsPlot
viz = ResidualsPlot(LinearRegression())
viz.fit(X_train, y_train)
viz.score(X_test, y_test)
viz.show()

# %%
subway = pd.read_csv("NYC_Transit_Subway_Entrance_And_Exit_Data.csv") 
subway.head()
# Out:
#   Division      Line Station Name  Station Latitude  Station Longitude Route1  \
# 0      BMT  4 Avenue      25th St         40.660397         -73.998091      R
# 1      BMT  4 Avenue      25th St         40.660397         -73.998091      R
# 2      BMT  4 Avenue      36th St         40.655144         -74.003549      N
# 3      BMT  4 Avenue      36th St         40.655144         -74.003549      N
# 4      BMT  4 Avenue      36th St         40.655144         -74.003549      N
#
#   Route2 Route3 Route4 Route5  ...    ADA ADA Notes  Free Crossover  \
# 0    NaN    NaN    NaN    NaN  ...  False       NaN           False
# 1    NaN    NaN    NaN    NaN  ...  False       NaN           False
# 2      R    NaN    NaN    NaN  ...  False       NaN            True
# 3      R    NaN    NaN    NaN  ...  False       NaN            True
# 4      R    NaN    NaN    NaN  ...  False       NaN            True
#
#    North South Street  East West Street  Corner Entrance Latitude  \
# 0             4th Ave           25th St      SW         40.660489
# 1             4th Ave           25th St      SE         40.660323
# 2             4th Ave           36th St      NW         40.654676
# 3             4th Ave           36th St      NE         40.654365
# 4             4th Ave           36th St      NW         40.654490
#
#   Entrance Longitude         Station Location        Entrance Location
# 0         -73.998220  (40.660397, -73.998091)   (40.660489, -73.99822)
# 1         -73.997952  (40.660397, -73.998091)  (40.660323, -73.997952)
# 2         -74.004306  (40.655144, -74.003549)  (40.654676, -74.004306)
# 3         -74.004113  (40.655144, -74.003549)  (40.654365, -74.004113)
# 4         -74.004499  (40.655144, -74.003549)   (40.65449, -74.004499)
#
# [5 rows x 32 columns]

# %%
#to get a count of missing values for each column, and what percent of each column is null 
subway.isnull().sum()

total = subway.isnull().sum().sort_values(ascending=False)
percent = (subway.isnull().sum())/subway.isnull().count().sort_values(ascending=False)

missing_data_2 = pd.concat([total, percent], axis=1, keys=['Total','Percent'], sort=False).sort_values('Total', ascending=False)
missing_data_2.head(25)
# Out:
#                     Total   Percent
# Route11              1845  0.987687
# Route10              1845  0.987687
# Route9               1840  0.985011
# Staff Hours          1828  0.978587
# Route8               1820  0.974304
# Exit Only            1812  0.970021
# ADA Notes            1793  0.959850
# Route7               1788  0.957173
# Route6               1741  0.932013
# Route5               1630  0.872591
# Route4               1547  0.828158
# Route3               1374  0.735546
# Route2                848  0.453961
# East West Street       35  0.018737
# Corner                 32  0.017131
# North South Street     29  0.015525
# Entry                   0  0.000000
# Entrance Longitude      0  0.000000
# Entrance Latitude       0  0.000000
# Free Crossover          0  0.000000
# ADA                     0  0.000000
# Staffing                0  0.000000
# Vending                 0  0.000000
# Route1                  0  0.000000
# Entrance Type           0  0.000000

# %%
#remove columns with less than 50%
def less_than_50_percent(colname):
    total_row = subway.shape[0]
    isnull_count = subway[colname].isna().sum()
    if isnull_count/total_row > .4:
        return True

# %%
columns = list(subway)
remove_columns_0 = []
for column in columns:
    remove_column_y_n = less_than_50_percent(column)
    if remove_column_y_n:
        remove_columns_0.append(column)

print(remove_columns_0)
# Out:
# ['Route2', 'Route3', 'Route4', 'Route5', 'Route6', 'Route7', 'Route8', 'Route9', 'Route10', 'Route11', 'Exit Only', 'Staff Hours', 'ADA Notes']

# %%
subway.shape
# Out:
# (1868, 32)

# %%
subway.isnull().sum()
# Out:
# Division                 0
# Line                     0
# Station Name             0
# Station Latitude         0
# Station Longitude        0
# Route1                   0
# Route2                 848
# Route3                1374
# Route4                1547
# Route5                1630
# Route6                1741
# Route7                1788
# Route8                1820
# Route9                1840
# Route10               1845
# Route11               1845
# Entrance Type            0
# Entry                    0
# Exit Only             1812
# Vending                  0
# Staffing                 0
# Staff Hours           1828
# ADA                      0
# ADA Notes             1793
# Free Crossover           0
# North South Street      29
# East West Street        35
# Corner                  32
# Entrance Latitude        0
# Entrance Longitude       0
# Station Location         0
# Entrance Location        0
# dtype: int64

# %%
column_with_nan = subway.columns[subway.isnull().any()]

for column in column_with_nan:
     print(column, subway[column].isnull().sum())
# Out:
# Route2 848
# Route3 1374
# Route4 1547
# Route5 1630
# Route6 1741
# Route7 1788
# Route8 1820
# Route9 1840
# Route10 1845
# Route11 1845
# Exit Only 1812
# Staff Hours 1828
# ADA Notes 1793
# North South Street 29
# East West Street 35
# Corner 32

# %%
for column in column_with_nan:
    if subway[column].isnull().sum()*100.0 > 50:
        subway.drop(column,1, inplace=True)

# %%
subway.shape
# Out:
# (1868, 16)

# %%
subway.head(5)
# Out:
#   Division      Line Station Name  Station Latitude  Station Longitude Route1  \
# 0      BMT  4 Avenue      25th St         40.660397         -73.998091      R
# 1      BMT  4 Avenue      25th St         40.660397         -73.998091      R
# 2      BMT  4 Avenue      36th St         40.655144         -74.003549      N
# 3      BMT  4 Avenue      36th St         40.655144         -74.003549      N
# 4      BMT  4 Avenue      36th St         40.655144         -74.003549      N
#
#   Entrance Type Entry Vending Staffing    ADA  Free Crossover  \
# 0         Stair   YES     YES     NONE  False           False
# 1         Stair   YES     YES     FULL  False           False
# 2         Stair   YES     YES     FULL  False            True
# 3         Stair   YES     YES     FULL  False            True
# 4         Stair   YES     YES     FULL  False            True
#
#    Entrance Latitude  Entrance Longitude         Station Location  \
# 0          40.660489          -73.998220  (40.660397, -73.998091)
# 1          40.660323          -73.997952  (40.660397, -73.998091)
# 2          40.654676          -74.004306  (40.655144, -74.003549)
# 3          40.654365          -74.004113  (40.655144, -74.003549)
# 4          40.654490          -74.004499  (40.655144, -74.003549)
#
#          Entrance Location
# 0   (40.660489, -73.99822)
# 1  (40.660323, -73.997952)
# 2  (40.654676, -74.004306)
# 3  (40.654365, -74.004113)
# 4   (40.65449, -74.004499)
