# %% [markdown]
# # Exploring the Data
# This is using NY data. Looks like inside aribnb data is same format so it can be used for other cities

# %%
import os
import io
import re
import numpy as np;
import pandas as pd;
import matplotlib;
import matplotlib.pyplot as plt;
import seaborn as sns;

import warnings
warnings.filterwarnings('ignore')

# %%
#read data, specify index so it's easier to join and search using loc
path = '../data/new-york-city-airbnb-open-data/'
listings_csv = os.path.join(path,'selected_columns_listings.csv')

listings = pd.read_csv(listings_csv, delimiter='\t', index_col = 'id')

# %%
#shape
listings.shape
#head
listings.head()
# Out:
#             scrape_id                                              name  \
# id
# 4662889  2.020031e+13                 Pre-War Apt on Central Park West!
# 4663804  2.020031e+13                 Cozy Room by CentralPark-Times Sq
# 4663807  2.020031e+13  Entire 2 Bedroom Apartment - 20 min to Times Sqr
# 4666584  2.020031e+13                    Unique 2 Bed/2 Bath Duplex Apt
# 4666794  2.020031e+13                   Cozy Bedroom in Large Apartment
#
#                                                picture_url      host_id  \
# id
# 4662889  https://a0.muscache.com/im/pictures/be4ddf2f-1...  2.40416e+07
# 4663804  https://a0.muscache.com/im/pictures/59490097/4...  2.41321e+07
# 4663807  https://a0.muscache.com/im/pictures/5d8b6998-6...  4.09854e+06
# 4666584  https://a0.muscache.com/im/pictures/59009723/d...  2.41446e+07
# 4666794  https://a0.muscache.com/im/pictures/5a65bd6b-9...  1.85114e+07
#
#          host_since host_response_time host_response_rate  \
# id
# 4662889  2014-11-22                NaN                NaN
# 4663804  2014-11-25                NaN                NaN
# 4663807  2012-11-08                NaN                NaN
# 4666584  2014-11-25     within an hour               100%
# 4666794  2014-07-20                NaN                NaN
#
#         host_acceptance_rate host_is_superhost  host_neighbourhood  ...  \
# id                                                                  ...
# 4662889                  NaN                 f     Upper West Side  ...
# 4663804                  NaN                 f      Hell's Kitchen  ...
# 4663807                  NaN                 f                 NaN  ...
# 4666584                 100%                 t              Harlem  ...
# 4666794                   0%                 f  Ditmars / Steinway  ...
#
#         review_scores_rating review_scores_accuracy review_scores_cleanliness  \
# id
# 4662889                100.0                    9.0                      10.0
# 4663804                 60.0                    4.0                       6.0
# 4663807                 90.0                    9.0                       9.0
# 4666584                 94.0                   10.0                      10.0
# 4666794                100.0                   10.0                      10.0
#
#         review_scores_checkin review_scores_communication  \
# id
# 4662889                  10.0                        10.0
# 4663804                  10.0                        10.0
# 4663807                  10.0                        10.0
# 4666584                  10.0                        10.0
# 4666794                  11.0                        11.0
#
#         review_scores_location review_scores_value instant_bookable  \
# id
# 4662889                   10.0                10.0                f
# 4663804                   10.0                 4.0                f
# 4663807                    9.0                10.0                f
# 4666584                    9.0                 9.0                t
# 4666794                   11.0                11.0                f
#
#                  cancellation_policy reviews_per_month
# id
# 4662889                     flexible              0.09
# 4663804  strict_14_with_grace_period              0.02
# 4663807  strict_14_with_grace_period              0.04
# 4666584  strict_14_with_grace_period              0.83
# 4666794  strict_14_with_grace_period              0.03
#
# [5 rows x 55 columns]

# %%
#to get all columns, set option
pd.set_option('display.max_columns', 107)
#to get text with no truncation
pd.set_option('display.max_colwidth', -1)

# %%
#all colums
list(listings.columns.values)
# Out:
# ['scrape_id',
#  'name',
#  'picture_url',
#  'host_id',
#  'host_since',
#  'host_response_time',
#  'host_response_rate',
#  'host_acceptance_rate',
#  'host_is_superhost',
#  'host_neighbourhood',
#  'host_listings_count',
#  'host_verifications',
#  'host_has_profile_pic',
#  'host_identity_verified',
#  'street',
#  'neighbourhood',
#  'neighbourhood_cleansed',
#  'calc_neighbourhod_listing_is_wrong',
#  'neighbourhood_group_cleansed',
#  'city',
#  'state',
#  'zipcode',
#  'latitude',
#  'longitude',
#  'is_location_exact',
#  'property_type',
#  'room_type',
#  'accommodates',
#  'bathrooms',
#  'bedrooms',
#  'beds',
#  'bed_type',
#  'amenities',
#  'price',
#  'security_deposit',
#  'cleaning_fee',
#  'guests_included',
#  'extra_people',
#  'minimum_nights',
#  'maximum_nights',
#  'calendar_updated',
#  'number_of_reviews',
#  'number_of_reviews_ltm',
#  'first_review',
#  'last_review',
#  'review_scores_rating',
#  'review_scores_accuracy',
#  'review_scores_cleanliness',
#  'review_scores_checkin',
#  'review_scores_communication',
#  'review_scores_location',
#  'review_scores_value',
#  'instant_bookable',
#  'cancellation_policy',
#  'reviews_per_month']

# %%
#new df, select only few
listings_select = listings[[
 'host_since',
  'host_response_time',
#  'calc_neighbourhod_listing_is_wrong',
#  'neighbourhood_group_cleansed',
#  'property_type',
#  'room_type',
#  'accommodates',
  'bathrooms',
  'bedrooms',
  'beds',
#  'bed_type',
#  'amenities',
 'price',
  'security_deposit',
  'cleaning_fee',
  'guests_included',
  'extra_people',
#  'calendar_updated',
  'number_of_reviews'#,
#  'review_scores_rating',
#  'review_scores_accuracy',
#  'review_scores_cleanliness',
#  'review_scores_checkin',
#  'review_scores_communication',
#  'review_scores_location',
#  'review_scores_value',
#  'instant_bookable',
#  'cancellation_policy',
# 'reviews_per_month'
]]

# %%
#heatmap for all int/float columns
plt.figure(figsize=(12,10))
correlations = listings_select.corr()
sns.heatmap(correlations,
           cmap='coolwarm');

# %%
# Using the Seaborn Pairplot to get cross plots between different attributes
sns.pairplot(listings_select);
