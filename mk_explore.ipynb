# %% [markdown]
# # Exploring the Data
# This is using Austin data. Looks like inside aribnb data is same format so it can be used for other cities

# %%
import numpy as np;
import pandas as pd;
import matplotlib;
import matplotlib.pyplot as plt;
import seaborn as sns;

import warnings
warnings.filterwarnings('ignore')

# %%
#listing for 702825
listings = pd.read_csv('data/austin-airbnb/listings.csv')
listings[listings.id == 702825]
# Out:
#          id                          listing_url       scrape_id last_scraped  \
# 301  702825  https://www.airbnb.com/rooms/702825  20200219033646   2020-02-19
#
#                                   name  \
# 301  MOD CASA 78704, close to DOWNTOWN
#
#                                                summary  \
# 301  3 bedrooms connected by open loft-like space.....
#
#                                                  space  \
# 301  STR Type II Your fee includes the 11% Short Te...
#
#                                            description experiences_offered  \
# 301  3 bedrooms connected by open loft-like space.....                none
#
#                                  neighborhood_overview  ... instant_bookable  \
# 301  Dawson hood. Perfect 78704 location to be arou...  ...                t
#
#     is_business_travel_ready          cancellation_policy  \
# 301                        f  strict_14_with_grace_period
#
#     require_guest_profile_picture require_guest_phone_verification  \
# 301                             t                                t
#
#      calculated_host_listings_count  \
# 301                               1
#
#      calculated_host_listings_count_entire_homes  \
# 301                                            1
#
#     calculated_host_listings_count_private_rooms  \
# 301                                            0
#
#      calculated_host_listings_count_shared_rooms  reviews_per_month
# 301                                            0               1.97
#
# [1 rows x 106 columns]

# %%
#get all columns
listings.info(verbose=True, null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11520 entries, 0 to 11519
# Data columns (total 106 columns):
# id                                              11520 non-null int64
# listing_url                                     11520 non-null object
# scrape_id                                       11520 non-null int64
# last_scraped                                    11520 non-null object
# name                                            11520 non-null object
# summary                                         11124 non-null object
# space                                           8962 non-null object
# description                                     11333 non-null object
# experiences_offered                             11520 non-null object
# neighborhood_overview                           7809 non-null object
# notes                                           5540 non-null object
# transit                                         7200 non-null object
# access                                          6750 non-null object
# interaction                                     7690 non-null object
# house_rules                                     7861 non-null object
# thumbnail_url                                   0 non-null float64
# medium_url                                      0 non-null float64
# picture_url                                     11520 non-null object
# xl_picture_url                                  0 non-null float64
# host_id                                         11520 non-null int64
# host_url                                        11520 non-null object
# host_name                                       11518 non-null object
# host_since                                      11518 non-null object
# host_location                                   11493 non-null object
# host_about                                      7449 non-null object
# host_response_time                              7922 non-null object
# host_response_rate                              7922 non-null object
# host_acceptance_rate                            8849 non-null object
# host_is_superhost                               11518 non-null object
# host_thumbnail_url                              11518 non-null object
# host_picture_url                                11518 non-null object
# host_neighbourhood                              8964 non-null object
# host_listings_count                             11518 non-null float64
# host_total_listings_count                       11518 non-null float64
# host_verifications                              11520 non-null object
# host_has_profile_pic                            11518 non-null object
# host_identity_verified                          11518 non-null object
# street                                          11520 non-null object
# neighbourhood                                   10669 non-null object
# neighbourhood_cleansed                          11520 non-null int64
# neighbourhood_group_cleansed                    0 non-null float64
# city                                            11518 non-null object
# state                                           11516 non-null object
# zipcode                                         11430 non-null object
# market                                          11509 non-null object
# smart_location                                  11520 non-null object
# country_code                                    11520 non-null object
# country                                         11520 non-null object
# latitude                                        11520 non-null float64
# longitude                                       11520 non-null float64
# is_location_exact                               11520 non-null object
# property_type                                   11520 non-null object
# room_type                                       11520 non-null object
# accommodates                                    11520 non-null int64
# bathrooms                                       11506 non-null float64
# bedrooms                                        11515 non-null float64
# beds                                            11480 non-null float64
# bed_type                                        11520 non-null object
# amenities                                       11520 non-null object
# square_feet                                     193 non-null float64
# price                                           11520 non-null object
# weekly_price                                    888 non-null object
# monthly_price                                   747 non-null object
# security_deposit                                8461 non-null object
# cleaning_fee                                    9487 non-null object
# guests_included                                 11520 non-null int64
# extra_people                                    11520 non-null object
# minimum_nights                                  11520 non-null int64
# maximum_nights                                  11520 non-null int64
# minimum_minimum_nights                          11520 non-null int64
# maximum_minimum_nights                          11520 non-null int64
# minimum_maximum_nights                          11520 non-null int64
# maximum_maximum_nights                          11520 non-null int64
# minimum_nights_avg_ntm                          11520 non-null float64
# maximum_nights_avg_ntm                          11520 non-null float64
# calendar_updated                                11520 non-null object
# has_availability                                11520 non-null object
# availability_30                                 11520 non-null int64
# availability_60                                 11520 non-null int64
# availability_90                                 11520 non-null int64
# availability_365                                11520 non-null int64
# calendar_last_scraped                           11520 non-null object
# number_of_reviews                               11520 non-null int64
# number_of_reviews_ltm                           11520 non-null int64
# first_review                                    9053 non-null object
# last_review                                     9053 non-null object
# review_scores_rating                            8939 non-null float64
# review_scores_accuracy                          8929 non-null float64
# review_scores_cleanliness                       8929 non-null float64
# review_scores_checkin                           8928 non-null float64
# review_scores_communication                     8928 non-null float64
# review_scores_location                          8923 non-null float64
# review_scores_value                             8924 non-null float64
# requires_license                                11520 non-null object
# license                                         39 non-null object
# jurisdiction_names                              11520 non-null object
# instant_bookable                                11520 non-null object
# is_business_travel_ready                        11520 non-null object
# cancellation_policy                             11520 non-null object
# require_guest_profile_picture                   11520 non-null object
# require_guest_phone_verification                11520 non-null object
# calculated_host_listings_count                  11520 non-null int64
# calculated_host_listings_count_entire_homes     11520 non-null int64
# calculated_host_listings_count_private_rooms    11520 non-null int64
# calculated_host_listings_count_shared_rooms     11520 non-null int64
# reviews_per_month                               9053 non-null float64
# dtypes: float64(22), int64(22), object(62)
# memory usage: 9.3+ MB

# %%
#look at column value for one record
listings['space'][listings.id == 702825]
# Out:
# 301    STR Type II Your fee includes the 11% Short Te...
# Name: space, dtype: object

# %%
#availability for 702825?
calendar = pd.read_csv('data/austin-airbnb/calendar.csv')
calendar[calendar.listing_id == 702825].head()
# Out:
#    listing_id        date available    price adjusted_price  minimum_nights  \
# 0      702825  2020-02-19         f  $260.00        $260.00               3
# 1      702825  2020-02-20         f  $260.00        $260.00               3
# 2      702825  2020-02-21         f  $275.00        $275.00               3
# 3      702825  2020-02-22         f  $275.00        $275.00               3
# 4      702825  2020-02-23         f  $260.00        $260.00               3
#
#    maximum_nights
# 0             120
# 1             120
# 2             120
# 3             120
# 4             120

# %%
#review for 702825, comments doesn't indicate postive or negative
reviews =  pd.read_csv('data/austin-airbnb/reviews.csv')
reviews[reviews.listing_id == 702825].head()
# Out:
#        listing_id       id        date  reviewer_id reviewer_name  \
# 29272      702825  3400312  2013-01-23      4168467        Edward
# 29273      702825  3780244  2013-03-14      2102026        Lorena
# 29274      702825  4379954  2013-05-01      4591113          Alex
# 29275      702825  5605942  2013-07-08      6531262        Joseph
# 29276      702825  6078576  2013-07-29      1972287         Trish
#
#                                                 comments
# 29272  We had a longer-term stay at Larry's place.\r\...
# 29273  Larrys home was spacious and beautiful, with a...
# 29274  We had a lovely (Email hidden by Airbnb) munic...
# 29275  A very nice, modern, and spacious home located...
# 29276  Larry was a fabulous host. He left lots of goo...

# %%
#data shape
print('listings: ' + str(listings.shape))
print('calendar: ' + str(calendar.shape))
print('reviews: ' + str(reviews.shape))
# Out:
# listings: (11520, 106)
# calendar: (4204800, 7)
# reviews: (359504, 6)

# %%
#new data frame only for data types float or integer
listings_plot = listings[[#'id','scrape_id','host_id','host_listings_count',
                          'host_total_listings_count','neighbourhood_cleansed',
                          #'latitude','longitude',
                          'accommodates','bathrooms',
                          'bedrooms','beds','guests_included',
                          #'minimum_nights','maximum_nights',
                          #'minimum_minimum_nights','maximum_minimum_nights',
                          #'minimum_maximum_nights','maximum_maximum_nights',
                          #'minimum_nights_avg_ntm','maximum_nights_avg_ntm',
                          #'availability_30','availability_60','availability_90','availability_365',
                          #'number_of_reviews','number_of_reviews_ltm','review_scores_rating','review_scores_accuracy',
                          #'review_scores_cleanliness','review_scores_checkin','review_scores_communication',
                          #'review_scores_location','review_scores_value','reviews_per_month'
                          #'calculated_host_listings_count','calculated_host_listings_count_entire_homes',
                          #'calculated_host_listings_count_private_rooms','calculated_host_listings_count_shared_rooms'
                         ]]

# %%
# Using the Seaborn Pairplot to get cross plots between different attributes
sns.pairplot(listings_plot);
